# %% [markdown]
# This is the conversion of the RData file into feather necessary for the refactoring of agoradataprocessing.

# %%
library(synapser)
library(feather)
library(dplyr)
library(purrr)

synLogin()

metabolomics_rdata <- synGet(entity='syn19001410')
load(metabolomics_rdata$path)
ls()
# Out:
# Welcome, Matthew Fazza!
# NULL
# [1] "agora.metabolite.gene.associations" "agora.metabolite.stats"
# [3] "metabolite_gene_associations"       "metabolomics_rdata"

# %%
sapply(agora.metabolite.gene.associations, class)
metabolite_gene_associations <- as.data.frame(agora.metabolite.gene.associations)
# Out:
#       associated.gene.name            ensembl.gene.id
#                   "factor"                   "factor"
#              metabolite.id       metabolite.full.name
#                   "factor"                   "factor"
#              association.p gene.wide.p.threshold.1KGP
#                  "numeric"                  "numeric"

# %%
# sapply(agora.metabolite.stats, class)
# metabolite_stats <- as.data.frame(agora.metabolite.stats)

map(agora.metabolite.stats, as.data.frame)
# Out:
# Error in (function (..., row.names = NULL, check.rows = FALSE, check.names = TRUE, : arguments imply differing number of rows: 1, 5, 2
# Traceback:
#
# 1. map(agora.metabolite.stats, as.data.frame)
# 2. .f(.x[[i]], ...)
# 3. .f(.x[[i]], ...)
# 4. as.data.frame.list(.x[[i]], ...)
# 5. do.call(data.frame, c(x, alis))
# 6. (function (..., row.names = NULL, check.rows = FALSE, check.names = TRUE,
#  .     fix.empty.names = TRUE, stringsAsFactors = default.stringsAsFactors())
#  . {
#  .     data.row.names <- if (check.rows && is.null(row.names))
#  .         function(current, new, i) {
#  .             if (is.character(current))
#  .                 new <- as.character(new)
#  .             if (is.character(new))
#  .                 current <- as.character(current)
#  .             if (anyDuplicated(new))
#  .                 return(current)
#  .             if (is.null(current))
#  .                 return(new)
#  .             if (all(current == new) || all(current == ""))
#  .                 return(new)
#  .             stop(gettextf("mismatch of row names in arguments of 'data.frame', item %d",
#  .                 i), domain = NA)
#  .         }
#  .     else function(current, new, i) {
#  .         if (is.null(current)) {
#  .             if (anyDuplicated(new)) {
#  .                 warning(gettextf("some row.names duplicated: %s --> row.names NOT used",
#  .                   paste(which(duplicated(new)), collapse = ",")),
#  .                   domain = NA)
#  .                 current
#  .             }
#  .             else new
#  .         }
#  .         else current
#  .     }
#  .     object <- as.list(substitute(list(...)))[-1L]
#  .     mirn <- missing(row.names)
#  .     mrn <- is.null(row.names)
#  .     x <- list(...)
#  .     n <- length(x)
#  .     if (n < 1L) {
#  .         if (!mrn) {
#  .             if (is.object(row.names) || !is.integer(row.names))
#  .                 row.names <- as.character(row.names)
#  .             if (anyNA(row.names))
#  .                 stop("row names contain missing values")
#  .             if (anyDuplicated(row.names))
#  .                 stop(gettextf("duplicate row.names: %s", paste(unique(row.names[duplicated(row.names)]),
#  .                   collapse = ", ")), domain = NA)
#  .         }
#  .         else row.names <- integer()
#  .         return(structure(list(), names = character(), row.names = row.names,
#  .             class = "data.frame"))
#  .     }
#  .     vnames <- names(x)
#  .     if (length(vnames) != n)
#  .         vnames <- character(n)
#  .     no.vn <- !nzchar(vnames)
#  .     vlist <- vnames <- as.list(vnames)
#  .     nrows <- ncols <- integer(n)
#  .     for (i in seq_len(n)) {
#  .         xi <- if (is.character(x[[i]]) || is.list(x[[i]]))
#  .             as.data.frame(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
#  .         else as.data.frame(x[[i]], optional = TRUE)
#  .         nrows[i] <- .row_names_info(xi)
#  .         ncols[i] <- length(xi)
#  .         namesi <- names(xi)
#  .         if (ncols[i] > 1L) {
#  .             if (length(namesi) == 0L)
#  .                 namesi <- seq_len(ncols[i])
#  .             vnames[[i]] <- if (no.vn[i])
#  .                 namesi
#  .             else paste(vnames[[i]], namesi, sep = ".")
#  .         }
#  .         else if (length(namesi)) {
#  .             vnames[[i]] <- namesi
#  .         }
#  .         else if (fix.empty.names && no.vn[[i]]) {
#  .             tmpname <- deparse(object[[i]], nlines = 1L)[1L]
#  .             if (startsWith(tmpname, "I(") && endsWith(tmpname,
#  .                 ")")) {
#  .                 ntmpn <- nchar(tmpname, "c")
#  .                 tmpname <- substr(tmpname, 3L, ntmpn - 1L)
#  .             }
#  .             vnames[[i]] <- tmpname
#  .         }
#  .         if (mirn && nrows[i] > 0L) {
#  .             rowsi <- attr(xi, "row.names")
#  .             if (any(nzchar(rowsi)))
#  .                 row.names <- data.row.names(row.names, rowsi,
#  .                   i)
#  .         }
#  .         nrows[i] <- abs(nrows[i])
#  .         vlist[[i]] <- xi
#  .     }
#  .     nr <- max(nrows)
#  .     for (i in seq_len(n)[nrows < nr]) {
#  .         xi <- vlist[[i]]
#  .         if (nrows[i] > 0L && (nr%%nrows[i] == 0L)) {
#  .             xi <- unclass(xi)
#  .             fixed <- TRUE
#  .             for (j in seq_along(xi)) {
#  .                 xi1 <- xi[[j]]
#  .                 if (is.vector(xi1) || is.factor(xi1))
#  .                   xi[[j]] <- rep(xi1, length.out = nr)
#  .                 else if (is.character(xi1) && inherits(xi1, "AsIs"))
#  .                   xi[[j]] <- structure(rep(xi1, length.out = nr),
#  .                     class = class(xi1))
#  .                 else if (inherits(xi1, "Date") || inherits(xi1,
#  .                   "POSIXct"))
#  .                   xi[[j]] <- rep(xi1, length.out = nr)
#  .                 else {
#  .                   fixed <- FALSE
#  .                   break
#  .                 }
#  .             }
#  .             if (fixed) {
#  .                 vlist[[i]] <- xi
#  .                 next
#  .             }
#  .         }
#  .         stop(gettextf("arguments imply differing number of rows: %s",
#  .             paste(unique(nrows), collapse = ", ")), domain = NA)
#  .     }
#  .     value <- unlist(vlist, recursive = FALSE, use.names = FALSE)
#  .     vnames <- as.character(unlist(vnames[ncols > 0L]))
#  .     if (fix.empty.names && any(noname <- !nzchar(vnames)))
#  .         vnames[noname] <- paste0("Var.", seq_along(vnames))[noname]
#  .     if (check.names) {
#  .         if (fix.empty.names)
#  .             vnames <- make.names(vnames, unique = TRUE)
#  .         else {
#  .             nz <- nzchar(vnames)
#  .             vnames[nz] <- make.names(vnames[nz], unique = TRUE)
#  .         }
#  .     }
#  .     names(value) <- vnames
#  .     if (!mrn) {
#  .         if (length(row.names) == 1L && nr != 1L) {
#  .             if (is.character(row.names))
#  .                 row.names <- match(row.names, vnames, 0L)
#  .             if (length(row.names) != 1L || row.names < 1L ||
#  .                 row.names > length(vnames))
#  .                 stop("'row.names' should specify one of the variables")
#  .             i <- row.names
#  .             row.names <- value[[i]]
#  .             value <- value[-i]
#  .         }
#  .         else if (!is.null(row.names) && length(row.names) !=
#  .             nr)
#  .             stop("row names supplied are of the wrong length")
#  .     }
#  .     else if (!is.null(row.names) && length(row.names) != nr) {
#  .         warning("row names were found from a short variable and have been discarded")
#  .         row.names <- NULL
#  .     }
#  .     class(value) <- "data.frame"
#  .     if (is.null(row.names))
#  .         attr(value, "row.names") <- .set_row_names(nr)
#  .     else {
#  .         if (is.object(row.names) || !is.integer(row.names))
#  .             row.names <- as.character(row.names)
#  .         if (anyNA(row.names))
#  .             stop("row names contain missing values")
#  .         if (anyDuplicated(row.names))
#  .             stop(gettextf("duplicate row.names: %s", paste(unique(row.names[duplicated(row.names)]),
#  .                 collapse = ", ")), domain = NA)
#  .         row.names(value) <- row.names
#  .     }
#  .     value
#  . })(metabolite.id = "C0", metabolite.full.name = "C0", boxplot.stats = structure(c(-2.24301895074324,
#  . -0.563261791496518, 0.0360000053536109, 0.697211583786713, 2.31925770410694,
#  . -2.3261094167728, -0.616879031427269, -0.0350410744613008, 0.624392218512684,
#  . 2.35297397043231), .Dim = c(5L, 2L)), n.per.group = c(362, 302
#  . ), boxplot.group.names = c("CN", "AD"), AD.diagnosis.p.value = 0.283589608291955,
#  .     check.names = TRUE, fix.empty.names = TRUE, stringsAsFactors = FALSE)
# 7. stop(gettextf("arguments imply differing number of rows: %s",
#  .     paste(unique(nrows), collapse = ", ")), domain = NA)

# %%
feather::write_feather(as.data.frame(agora.metabolite.gene.associations), 'metabolite_gene_associations.feather')
feather::write_feather(as.data.frame(agora.metabolite.stats), 'metabolite_stats.feather')
# Out:
# Error in (function (..., row.names = NULL, check.rows = FALSE, check.names = TRUE, : arguments imply differing number of rows: 1, 5, 2
# Traceback:
#
# 1. feather::write_feather(as.data.frame(agora.metabolite.stats),
#  .     "metabolite_stats.feather")
# 2. is.data.frame(x)
# 3. as.data.frame(agora.metabolite.stats)
# 4. as.data.frame(agora.metabolite.stats)
# 5. as.data.frame.list(agora.metabolite.stats)
# 6. do.call(data.frame, c(x, alis))
# 7. (function (..., row.names = NULL, check.rows = FALSE, check.names = TRUE,
#  .     fix.empty.names = TRUE, stringsAsFactors = default.stringsAsFactors())
#  . {
#  .     data.row.names <- if (check.rows && is.null(row.names))
#  .         function(current, new, i) {
#  .             if (is.character(current))
#  .                 new <- as.character(new)
#  .             if (is.character(new))
#  .                 current <- as.character(current)
#  .             if (anyDuplicated(new))
#  .                 return(current)
#  .             if (is.null(current))
#  .                 return(new)
#  .             if (all(current == new) || all(current == ""))
#  .                 return(new)
#  .             stop(gettextf("mismatch of row names in arguments of 'data.frame', item %d",
#  .                 i), domain = NA)
#  .         }
#  .     else function(current, new, i) {
#  .         if (is.null(current)) {
#  .             if (anyDuplicated(new)) {
#  .                 warning(gettextf("some row.names duplicated: %s --> row.names NOT used",
#  .                   paste(which(duplicated(new)), collapse = ",")),
#  .                   domain = NA)
#  .                 current
#  .             }
#  .             else new
#  .         }
#  .         else current
#  .     }
#  .     object <- as.list(substitute(list(...)))[-1L]
#  .     mirn <- missing(row.names)
#  .     mrn <- is.null(row.names)
#  .     x <- list(...)
#  .     n <- length(x)
#  .     if (n < 1L) {
#  .         if (!mrn) {
#  .             if (is.object(row.names) || !is.integer(row.names))
#  .                 row.names <- as.character(row.names)
#  .             if (anyNA(row.names))
#  .                 stop("row names contain missing values")
#  .             if (anyDuplicated(row.names))
#  .                 stop(gettextf("duplicate row.names: %s", paste(unique(row.names[duplicated(row.names)]),
#  .                   collapse = ", ")), domain = NA)
#  .         }
#  .         else row.names <- integer()
#  .         return(structure(list(), names = character(), row.names = row.names,
#  .             class = "data.frame"))
#  .     }
#  .     vnames <- names(x)
#  .     if (length(vnames) != n)
#  .         vnames <- character(n)
#  .     no.vn <- !nzchar(vnames)
#  .     vlist <- vnames <- as.list(vnames)
#  .     nrows <- ncols <- integer(n)
#  .     for (i in seq_len(n)) {
#  .         xi <- if (is.character(x[[i]]) || is.list(x[[i]]))
#  .             as.data.frame(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
#  .         else as.data.frame(x[[i]], optional = TRUE)
#  .         nrows[i] <- .row_names_info(xi)
#  .         ncols[i] <- length(xi)
#  .         namesi <- names(xi)
#  .         if (ncols[i] > 1L) {
#  .             if (length(namesi) == 0L)
#  .                 namesi <- seq_len(ncols[i])
#  .             vnames[[i]] <- if (no.vn[i])
#  .                 namesi
#  .             else paste(vnames[[i]], namesi, sep = ".")
#  .         }
#  .         else if (length(namesi)) {
#  .             vnames[[i]] <- namesi
#  .         }
#  .         else if (fix.empty.names && no.vn[[i]]) {
#  .             tmpname <- deparse(object[[i]], nlines = 1L)[1L]
#  .             if (startsWith(tmpname, "I(") && endsWith(tmpname,
#  .                 ")")) {
#  .                 ntmpn <- nchar(tmpname, "c")
#  .                 tmpname <- substr(tmpname, 3L, ntmpn - 1L)
#  .             }
#  .             vnames[[i]] <- tmpname
#  .         }
#  .         if (mirn && nrows[i] > 0L) {
#  .             rowsi <- attr(xi, "row.names")
#  .             if (any(nzchar(rowsi)))
#  .                 row.names <- data.row.names(row.names, rowsi,
#  .                   i)
#  .         }
#  .         nrows[i] <- abs(nrows[i])
#  .         vlist[[i]] <- xi
#  .     }
#  .     nr <- max(nrows)
#  .     for (i in seq_len(n)[nrows < nr]) {
#  .         xi <- vlist[[i]]
#  .         if (nrows[i] > 0L && (nr%%nrows[i] == 0L)) {
#  .             xi <- unclass(xi)
#  .             fixed <- TRUE
#  .             for (j in seq_along(xi)) {
#  .                 xi1 <- xi[[j]]
#  .                 if (is.vector(xi1) || is.factor(xi1))
#  .                   xi[[j]] <- rep(xi1, length.out = nr)
#  .                 else if (is.character(xi1) && inherits(xi1, "AsIs"))
#  .                   xi[[j]] <- structure(rep(xi1, length.out = nr),
#  .                     class = class(xi1))
#  .                 else if (inherits(xi1, "Date") || inherits(xi1,
#  .                   "POSIXct"))
#  .                   xi[[j]] <- rep(xi1, length.out = nr)
#  .                 else {
#  .                   fixed <- FALSE
#  .                   break
#  .                 }
#  .             }
#  .             if (fixed) {
#  .                 vlist[[i]] <- xi
#  .                 next
#  .             }
#  .         }
#  .         stop(gettextf("arguments imply differing number of rows: %s",
#  .             paste(unique(nrows), collapse = ", ")), domain = NA)
#  .     }
#  .     value <- unlist(vlist, recursive = FALSE, use.names = FALSE)
#  .     vnames <- as.character(unlist(vnames[ncols > 0L]))
#  .     if (fix.empty.names && any(noname <- !nzchar(vnames)))
#  .         vnames[noname] <- paste0("Var.", seq_along(vnames))[noname]
#  .     if (check.names) {
#  .         if (fix.empty.names)
#  .             vnames <- make.names(vnames, unique = TRUE)
#  .         else {
#  .             nz <- nzchar(vnames)
#  .             vnames[nz] <- make.names(vnames[nz], unique = TRUE)
#  .         }
#  .     }
#  .     names(value) <- vnames
#  .     if (!mrn) {
#  .         if (length(row.names) == 1L && nr != 1L) {
#  .             if (is.character(row.names))
#  .                 row.names <- match(row.names, vnames, 0L)
#  .             if (length(row.names) != 1L || row.names < 1L ||
#  .                 row.names > length(vnames))
#  .                 stop("'row.names' should specify one of the variables")
#  .             i <- row.names
#  .             row.names <- value[[i]]
#  .             value <- value[-i]
#  .         }
#  .         else if (!is.null(row.names) && length(row.names) !=
#  .             nr)
#  .             stop("row names supplied are of the wrong length")
#  .     }
#  .     else if (!is.null(row.names) && length(row.names) != nr) {
#  .         warning("row names were found from a short variable and have been discarded")
#  .         row.names <- NULL
#  .     }
#  .     class(value) <- "data.frame"
#  .     if (is.null(row.names))
#  .         attr(value, "row.names") <- .set_row_names(nr)
#  .     else {
#  .         if (is.object(row.names) || !is.integer(row.names))
#  .             row.names <- as.character(row.names)
#  .         if (anyNA(row.names))
#  .             stop("row names contain missing values")
#  .         if (anyDuplicated(row.names))
#  .             stop(gettextf("duplicate row.names: %s", paste(unique(row.names[duplicated(row.names)]),
#  .                 collapse = ", ")), domain = NA)
#  .         row.names(value) <- row.names
#  .     }
#  .     value
#  . })(C0 = list(metabolite.id = "C0", metabolite.full.name = "C0",
#  .     boxplot.stats = structure(c(-2.24301895074324, -0.563261791496518,
#  .     0.0360000053536109, 0.697211583786713, 2.31925770410694,
#  .     -2.3261094167728, -0.616879031427269, -0.0350410744613008,
#  .     0.624392218512684, 2.35297397043231), .Dim = c(5L, 2L)),
#  .     n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.283589608291955), C10 = list(
#  .     metabolite.id = "C10", metabolite.full.name = "C10", boxplot.stats = structure(c(-2.21488232744507,
#  .     -0.648084993227385, -0.117811632209457, 0.461060180991451,
#  .     1.97516312612985, -2.37250103507258, -0.567255192599336,
#  .     0.0197034996905747, 0.647910775435634, 2.44806074827195), .Dim = c(5L,
#  .     2L)), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.146556599131028), C10.2 = list(
#  .     metabolite.id = "C10.2", metabolite.full.name = "C10:2",
#  .     boxplot.stats = structure(c(-2.01703485735532, -0.549783888214444,
#  .     0.0660392857889977, 0.562314524258296, 2.19171648656644,
#  .     -2.20244101875157, -0.523112532838821, 0.065494496820435,
#  .     0.619511771022753, 2.20567635584201), .Dim = c(5L, 2L)),
#  .     n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.786540687740836), C12 = list(
#  .     metabolite.id = "C12", metabolite.full.name = "C12", boxplot.stats = structure(c(-1.99234469208132,
#  .     -0.510692639192698, -0.0275349308110039, 0.478356033888081,
#  .     1.73966492323038, -1.81724454416056, -0.316349492849366,
#  .     0.210462810625442, 0.693258361082819, 2.03490669831641), .Dim = c(5L,
#  .     2L)), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.00303028247949031), C14.1 = list(
#  .     metabolite.id = "C14.1", metabolite.full.name = "C14:1",
#  .     boxplot.stats = structure(c(-2.45447095232099, -0.687170551479438,
#  .     -0.133693732290948, 0.562990947912309, 2.22558048281001,
#  .     -2.37709669853997, -0.63231910778927, 0.033134694256154,
#  .     0.732273103983595, 2.51607128086863), .Dim = c(5L, 2L)),
#  .     n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.0724725881186579), C14.1.OH = list(
#  .     metabolite.id = "C14.1.OH", metabolite.full.name = "C14:1-OH",
#  .     boxplot.stats = structure(c(-1.30845060537324, -0.428997774666329,
#  .     0.0677533842631742, 0.525309465951763, 1.92553924988533,
#  .     -1.88397505746916, -0.393707479067956, 0.167000068632929,
#  .     0.678821156431072, 2.10892186120936), .Dim = c(5L, 2L)),
#  .     n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.223746407756457), C14.2 = list(
#  .     metabolite.id = "C14.2", metabolite.full.name = "C14:2",
#  .     boxplot.stats = structure(c(-2.48224787862525, -0.674426919440846,
#  .     -0.0544863712663542, 0.556631062870064, 2.38405666839888,
#  .     -2.33335975424617, -0.488127344527032, 0.165378888213418,
#  .     0.763533376372513, 2.49396015928909), .Dim = c(5L, 2L)),
#  .     n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.00308614454885615), C16 = list(
#  .     metabolite.id = "C16", metabolite.full.name = "C16", boxplot.stats = structure(c(-2.47407448526049,
#  .     -0.637070535052482, 0.0781512036140397, 0.604967338863251,
#  .     2.44394505534509, -2.21899975853106, -0.583802929611167,
#  .     -0.00354182314017573, 0.685757449008, 2.56186693345907), .Dim = c(5L,
#  .     2L)), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.544193419576527), C16.1 = list(
#  .     metabolite.id = "C16.1", metabolite.full.name = "C16:1",
#  .     boxplot.stats = structure(c(-2.59577891385953, -0.723896724285084,
#  .     -0.0526978377318617, 0.576470268600263, 2.2515254705634,
#  .     -2.30533286164862, -0.488824210767699, 0.0998601202201389,
#  .     0.876185499241421, 2.83917450064567), .Dim = c(5L, 2L)),
#  .     n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.0194957234666289), C18 = list(
#  .     metabolite.id = "C18", metabolite.full.name = "C18", boxplot.stats = structure(c(-2.24937609106318,
#  .     -0.686254713267807, -0.0417295152763586, 0.588599546511298,
#  .     2.40557481345989, -2.25078876280013, -0.537025506585928,
#  .     0.0654804145920166, 0.701096734116641, 2.31746001791535), .Dim = c(5L,
#  .     2L)), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.0845041448035818), C18.1 = list(
#  .     metabolite.id = "C18.1", metabolite.full.name = "C18:1",
#  .     boxplot.stats = structure(c(-2.39663337914888, -0.643503701918562,
#  .     0.0550842966641607, 0.563269493126593, 2.29585060828275,
#  .     -2.64589060280329, -0.690130806493191, 0.137132161256334,
#  .     0.760901334855767, 2.09029897166178), .Dim = c(5L, 2L)),
#  .     n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .     "AD"), AD.diagnosis.p.value = 0.275828714367031), C18.2 = list(
#  .     metabolite.id = "C18.2", metabolite.full.name = "C18:2",
#  .     boxplot.stats = structure(c(-2.68765321563321, -0.67098804575181,
#  .     0.073726779726044, 0.679022061477963, 2.70134912080573, -1.84041787302508,
#  .     -0.426624075495357, 0.0872655459440008, 0.659597590747878,
#  .     1.86178701888086), .Dim = c(5L, 2L)), n.per.group = c(362,
#  .     302), boxplot.group.names = c("CN", "AD"), AD.diagnosis.p.value = 0.0875977642183646),
#  .     C2 = list(metabolite.id = "C2", metabolite.full.name = "C2",
#  .         boxplot.stats = structure(c(-2.57963335876937, -0.673874127479614,
#  .         0.00670894684096728, 0.659505391116398, 2.39194194717245,
#  .         -2.54077895266138, -0.710814966477826, -0.00742718989441816,
#  .         0.712513397839354, 2.29524994937111), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.7672047845255), C3 = list(
#  .         metabolite.id = "C3", metabolite.full.name = "C3", boxplot.stats = structure(c(-2.68113832795645,
#  .         -0.622385318934574, 0.0451096298324365, 0.758952693220015,
#  .         2.73242066557519, -2.61229142671668, -0.788034767793561,
#  .         -0.087116863500336, 0.547089081476732, 2.54237902566757
#  .         ), .Dim = c(5L, 2L)), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.105245252387977), C3.DC..C4.OH. = list(
#  .         metabolite.id = "C3.DC..C4.OH.", metabolite.full.name = "C3-DC (C4-OH)",
#  .         boxplot.stats = structure(c(-1.84791261513515, -0.399301636226774,
#  .         0.0883311480537013, 0.663344229856758, 2.21470013553182,
#  .         -2.07981405479102, -0.656106570403753, -0.144773754206418,
#  .         0.364882928266822, 1.83840144874722), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.00526898982160687), C4 = list(
#  .         metabolite.id = "C4", metabolite.full.name = "C4", boxplot.stats = structure(c(-2.62119003855817,
#  .         -0.648758220366769, 0.0463637122680522, 0.713985323123029,
#  .         2.62365838053298, -2.40820035501599, -0.693108875485142,
#  .         -0.176131593636909, 0.575383872207756, 2.3891062347731
#  .         ), .Dim = c(5L, 2L)), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.129528644304091), C4.1 = list(
#  .         metabolite.id = "C4.1", metabolite.full.name = "C4:1",
#  .         boxplot.stats = structure(c(-2.05032119848004, -0.528211364732653,
#  .         0.00508489020920602, 0.507023967828587, 1.99284396386373,
#  .         -2.39527138935874, -0.744443836135793, -0.121715644591914,
#  .         0.437667171561169, 2.16351951703666), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.60690216703567), C6..C4.1.DC. = list(
#  .         metabolite.id = "C6..C4.1.DC.", metabolite.full.name = "C6 (C4:1-DC)",
#  .         boxplot.stats = structure(c(-2.07882281738298, -0.570099376352646,
#  .         -0.00278077136970894, 0.529530642035373, 2.02897114803431,
#  .         -1.94354044245174, -0.505600997368157, 0.095023834133083,
#  .         0.560714428054035, 2.00351619958551), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.395540486489021), C5 = list(
#  .         metabolite.id = "C5", metabolite.full.name = "C5", boxplot.stats = structure(c(-2.30375334152062,
#  .         -0.627550480224868, 0.0921865527270399, 0.735567595926431,
#  .         2.74729105001024, -2.63877090663908, -0.78538894196897,
#  .         -0.121104096955763, 0.558995350470619, 2.20880481852055
#  .         ), .Dim = c(5L, 2L)), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0488769382432073), C5.DC..C6.OH. = list(
#  .         metabolite.id = "C5.DC..C6.OH.", metabolite.full.name = "C5-DC (C6-OH)",
#  .         boxplot.stats = structure(c(-2.28722583008039, -0.660087098302923,
#  .         -0.125864107776341, 0.535327895098989, 2.31793881181605,
#  .         -2.11986150036558, -0.583995680251566, 0.0426020399196369,
#  .         0.734321712592368, 2.51298321141051), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.11331154389412), C7.DC = list(
#  .         metabolite.id = "C7.DC", metabolite.full.name = "C7-DC",
#  .         boxplot.stats = structure(c(-2.39623403116253, -0.578818541419913,
#  .         -0.0067142907481111, 0.639599055268875, 2.39101693454161,
#  .         -2.60164277742377, -0.613509095360911, 0.0499986682600779,
#  .         0.727034621549337, 2.35186854376124), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.88333223765675), C8 = list(
#  .         metabolite.id = "C8", metabolite.full.name = "C8", boxplot.stats = structure(c(-1.94201253851658,
#  .         -0.51294824217101, 0.0199628484216355, 0.451512007523462,
#  .         1.75745489934985, -1.92733420285599, -0.40634365683652,
#  .         0.0666759661027003, 0.620771278558255, 2.12051827848566
#  .         ), .Dim = c(5L, 2L)), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.216657587807762), C9 = list(
#  .         metabolite.id = "C9", metabolite.full.name = "C9", boxplot.stats = structure(c(-2.37838197775779,
#  .         -0.622732438713788, 0.0335971727110498, 0.643116844200647,
#  .         2.49844685034872, -2.36400637190229, -0.638273049811154,
#  .         -0.125149155938413, 0.581313135288659, 2.34320498555856
#  .         ), .Dim = c(5L, 2L)), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.394810851782301), lysoPC.a.C16.0 = list(
#  .         metabolite.id = "lysoPC.a.C16.0", metabolite.full.name = "lysoPC a C16:0",
#  .         boxplot.stats = structure(c(-2.5430680332659, -0.653537795553351,
#  .         0.00549822101496642, 0.652943829032444, 2.56582087035953,
#  .         -2.72174711478817, -0.727461821092615, 0.00970222070578449,
#  .         0.606073464874909, 2.50260729438863), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.350673606916369), lysoPC.a.C16.1 = list(
#  .         metabolite.id = "lysoPC.a.C16.1", metabolite.full.name = "lysoPC a C16:1",
#  .         boxplot.stats = structure(c(-2.40622583592968, -0.685545511324417,
#  .         -0.0414934125457563, 0.554110410776106, 2.39343372685893,
#  .         -2.5703295020951, -0.622125218680667, 0.0564663075612227,
#  .         0.70363432084549, 2.33183535338795), .Dim = c(5L, 2L)),
#  .         n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.193871468642007), lysoPC.a.C17.0 = list(
#  .         metabolite.id = "lysoPC.a.C17.0", metabolite.full.name = "lysoPC a C17:0",
#  .         boxplot.stats = structure(c(-2.83554164650418, -0.729771715047797,
#  .         -0.00400493535347815, 0.696011209568889, 2.77543204632973,
#  .         -2.42073776334693, -0.664126732253579, 0.0437215859475571,
#  .         0.593606527840628, 2.41446452013281), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.817822458949038), lysoPC.a.C18.0 = list(
#  .         metabolite.id = "lysoPC.a.C18.0", metabolite.full.name = "lysoPC a C18:0",
#  .         boxplot.stats = structure(c(-2.21180095786563, -0.542589040637492,
#  .         0.00928657739456401, 0.6343655634273, 2.37198688056006,
#  .         -2.71866497587954, -0.742776156348661, -0.0380802836537366,
#  .         0.62774172835009, 2.50591399425746), .Dim = c(5L, 2L)),
#  .         n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.406681980626648), lysoPC.a.C18.1 = list(
#  .         metabolite.id = "lysoPC.a.C18.1", metabolite.full.name = "lysoPC a C18:1",
#  .         boxplot.stats = structure(c(-2.49328014760851, -0.692867915923627,
#  .         -0.058415898616506, 0.6691526126898, 2.55195976548334,
#  .         -2.46615619796758, -0.610736950397102, 0.0340518725392088,
#  .         0.63386276822134, 2.13679960144553), .Dim = c(5L, 2L)),
#  .         n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.78535482224079), lysoPC.a.C18.2 = list(
#  .         metabolite.id = "lysoPC.a.C18.2", metabolite.full.name = "lysoPC a C18:2",
#  .         boxplot.stats = structure(c(-2.67576420765001, -0.676313980569042,
#  .         0.0299689885921411, 0.716749895244155, 2.72501266841185,
#  .         -2.57024869309515, -0.649639495824938, 0.00618185497595886,
#  .         0.648606123896333, 2.48220634875674), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.923898112009854), lysoPC.a.C20.3 = list(
#  .         metabolite.id = "lysoPC.a.C20.3", metabolite.full.name = "lysoPC a C20:3",
#  .         boxplot.stats = structure(c(-2.11649586311239, -0.603072642326606,
#  .         0.043156818108566, 0.676828764822806, 2.49585805066157,
#  .         -2.60920226434874, -0.645433478368366, -0.00197928973908488,
#  .         0.694610086482795, 2.54471331325727), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.863169377969984), lysoPC.a.C20.4 = list(
#  .         metabolite.id = "lysoPC.a.C20.4", metabolite.full.name = "lysoPC a C20:4",
#  .         boxplot.stats = structure(c(-2.68877280540481, -0.662899933878646,
#  .         0.0653275694750011, 0.766040395535806, 2.60555314724277,
#  .         -2.62994716009636, -0.692926481077781, -0.0099867759916725,
#  .         0.641577299273797, 2.56220343371123), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.525589338336329), lysoPC.a.C24.0 = list(
#  .         metabolite.id = "lysoPC.a.C24.0", metabolite.full.name = "lysoPC a C24:0",
#  .         boxplot.stats = structure(c(-2.68146996947891, -0.716046022140206,
#  .         -0.0344319755773645, 0.606040921342944, 2.49868953952703,
#  .         -2.42005525025015, -0.640637783240087, 0.0264281488134661,
#  .         0.718531271330109, 2.6707109524416), .Dim = c(5L, 2L)),
#  .         n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.476139739867254), lysoPC.a.C28.1 = list(
#  .         metabolite.id = "lysoPC.a.C28.1", metabolite.full.name = "lysoPC a C28:1",
#  .         boxplot.stats = structure(c(-2.82751759052032, -0.725830913360737,
#  .         -0.0293734236988316, 0.726826358932339, 2.33599329361625,
#  .         -2.43390161688761, -0.590778477420209, 0.0504000285126718,
#  .         0.653534896618074, 2.39164426452576), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.648691227850808), PC.aa.C24.0 = list(
#  .         metabolite.id = "PC.aa.C24.0", metabolite.full.name = "PC aa C24:0",
#  .         boxplot.stats = structure(c(-2.46782775135287, -0.66765515611403,
#  .         -0.0710025404190658, 0.6468548304891, 2.60504818315133,
#  .         -2.40353060849578, -0.639075515216926, 0.00374407522760735,
#  .         0.632181683021925, 2.51646484381781), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.405482040299115), PC.aa.C28.1 = list(
#  .         metabolite.id = "PC.aa.C28.1", metabolite.full.name = "PC aa C28:1",
#  .         boxplot.stats = structure(c(-2.61171535701836, -0.667660141632146,
#  .         0.0835055507282645, 0.716073125573496, 2.76271404953245,
#  .         -2.44396944570404, -0.60123878704471, -0.0115549801718713,
#  .         0.640687179117421, 2.33435226399324), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.717440032444008), PC.aa.C30.0 = list(
#  .         metabolite.id = "PC.aa.C30.0", metabolite.full.name = "PC aa C30:0",
#  .         boxplot.stats = structure(c(-2.59132431774149, -0.765055461020676,
#  .         -0.0335696400686187, 0.657332585252284, 2.60356542402089,
#  .         -2.26435952806688, -0.672709863078674, 0.0036744168413696,
#  .         0.584310758970672, 2.29525172093159), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.924795702475143), PC.aa.C32.0 = list(
#  .         metabolite.id = "PC.aa.C32.0", metabolite.full.name = "PC aa C30:2",
#  .         boxplot.stats = structure(c(-2.44857670617943, -0.777146255604089,
#  .         -0.0649357737455272, 0.766756797167686, 2.82817328239739,
#  .         -2.39756309689717, -0.623659832334239, -0.0769717802967202,
#  .         0.584367543433795, 2.37099578553606), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.864633841585125), PC.aa.C32.1 = list(
#  .         metabolite.id = "PC.aa.C32.1", metabolite.full.name = "PC aa C32:1",
#  .         boxplot.stats = structure(c(-2.62218385585896, -0.651206725506796,
#  .         -0.0828177110688249, 0.679146980688808, 2.54638108385942,
#  .         -2.50484379959676, -0.696319096592664, 0.0288015739855957,
#  .         0.710614037136099, 2.77306515679663), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.673588423706373), PC.aa.C32.3 = list(
#  .         metabolite.id = "PC.aa.C32.3", metabolite.full.name = "PC aa C32:3",
#  .         boxplot.stats = structure(c(-2.44174818825243, -0.664434503591473,
#  .         0.0324923405928552, 0.651372670864044, 2.57954147928261,
#  .         -2.6495105459937, -0.717650674398543, 0.0612623058045907,
#  .         0.66228433632241, 2.36064369627927), .Dim = c(5L, 2L)),
#  .         n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.689369367436871), PC.aa.C34.1 = list(
#  .         metabolite.id = "PC.aa.C34.1", metabolite.full.name = "PC aa C34:1",
#  .         boxplot.stats = structure(c(-2.46876260187629, -0.58287083151635,
#  .         0.0119287438568528, 0.77520898975081, 2.78280527274767,
#  .         -2.31841040596988, -0.658562950485616, -0.0425819682071833,
#  .         0.538715195876115, 2.05131045490632), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.313120335450063), PC.aa.C34.3 = list(
#  .         metabolite.id = "PC.aa.C34.3", metabolite.full.name = "PC aa C34:3",
#  .         boxplot.stats = structure(c(-2.40551954777765, -0.708814474988495,
#  .         -0.0660873056953093, 0.725021626672595, 2.71966328347158,
#  .         -2.49894495008316, -0.587911582304376, 0.00709846051591122,
#  .         0.710944352952878, 2.5374019021702), .Dim = c(5L, 2L)),
#  .         n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.825906779868109), PC.aa.C34.4 = list(
#  .         metabolite.id = "PC.aa.C34.4", metabolite.full.name = "PC aa C34:4",
#  .         boxplot.stats = structure(c(-2.42164319391725, -0.617520173065506,
#  .         0.0872321864764773, 0.656992958128882, 2.53357885351638,
#  .         -2.45951389374095, -0.704522622997518, -0.0396598068684544,
#  .         0.578556220656982, 2.27795004476473), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.368228709960784), PC.aa.C36.0 = list(
#  .         metabolite.id = "PC.aa.C36.0", metabolite.full.name = "PC aa C36:0",
#  .         boxplot.stats = structure(c(-1.8059846953799, -0.364137156502069,
#  .         0.161007788802369, 0.620831281434945, 1.95095826673308,
#  .         -1.85931659681319, -0.497385886330637, 0.0859946256230681,
#  .         0.511891732613836, 1.88252051671539), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.00812872525519205), PC.aa.C36.1 = list(
#  .         metabolite.id = "PC.aa.C36.1", metabolite.full.name = "PC aa C36:1",
#  .         boxplot.stats = structure(c(-2.2733674917584, -0.566910117053629,
#  .         -0.0163884841927325, 0.703591005889968, 2.58938458001128,
#  .         -2.36446577670566, -0.648035651060949, 0.0241193782207396,
#  .         0.582487445055802, 2.338211191921), .Dim = c(5L, 2L)),
#  .         n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.216655642918743), PC.aa.C36.3 = list(
#  .         metabolite.id = "PC.aa.C36.3", metabolite.full.name = "PC aa C36:3",
#  .         boxplot.stats = structure(c(-2.13981322509457, -0.589594030764662,
#  .         0.0675565264707158, 0.748670118348694, 2.69167546974828,
#  .         -2.4395322196579, -0.647673028590421, -0.0627893424965065,
#  .         0.595669750231498, 2.11495664458228), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0173522836622415), PC.aa.C36.4 = list(
#  .         metabolite.id = "PC.aa.C36.4", metabolite.full.name = "PC aa C36:4",
#  .         boxplot.stats = structure(c(-2.50427735400799, -0.612476685060694,
#  .         0.118676727252453, 0.682113482896251, 2.4449640425178,
#  .         -2.45816320781535, -0.646086552656056, -0.0428019676547319,
#  .         0.570728788279131, 2.18166841720007), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.253783579543319), PC.aa.C36.5 = list(
#  .         metabolite.id = "PC.aa.C36.5", metabolite.full.name = "PC aa C36:5",
#  .         boxplot.stats = structure(c(-2.36380541923324, -0.657423820295477,
#  .         -0.0153325484226628, 0.70093796549909, 2.50459795572679,
#  .         -2.3482858195115, -0.676717132747612, -0.0389051369098384,
#  .         0.493811921702379, 1.98557270938249), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.131513681306239), PC.aa.C36.6 = list(
#  .         metabolite.id = "PC.aa.C36.6", metabolite.full.name = "PC aa C36:6",
#  .         boxplot.stats = structure(c(-2.20058414507984, -0.538027798816646,
#  .         0.0657464853419011, 0.664661732635415, 2.44428922289686,
#  .         -2.46831915889554, -0.652449046073823, -0.013497601924639,
#  .         0.574844551330408, 2.39638240053658), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.170029190188082), PC.aa.C38.0 = list(
#  .         metabolite.id = "PC.aa.C38.0", metabolite.full.name = "PC aa C38:0",
#  .         boxplot.stats = structure(c(-2.56928079090789, -0.659330693116964,
#  .         -0.00373579619209989, 0.71660032775356, 2.61574389008769,
#  .         -2.79917863799811, -0.757656123497326, -0.0178366087155251,
#  .         0.659491579785654, 2.46485109303092), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.288232520937947), PC.aa.C38.3 = list(
#  .         metabolite.id = "PC.aa.C38.3", metabolite.full.name = "PC aa C38:3",
#  .         boxplot.stats = structure(c(-3.06521270126699, -0.747658086718493,
#  .         0.0474377396410516, 0.826061398726007, 2.70426773570345,
#  .         -2.32714530343919, -0.735871450941291, 0.0351241353842142,
#  .         0.610675427925012, 2.57440099433318), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.118833960015699), PC.aa.C38.4 = list(
#  .         metabolite.id = "PC.aa.C38.4", metabolite.full.name = "PC aa C38:4",
#  .         boxplot.stats = structure(c(-2.64172700342721, -0.587269165124838,
#  .         0.135204952366075, 0.790741085307388, 2.2297159736528,
#  .         -2.53877027199445, -0.759496634844059, -0.0474667409187728,
#  .         0.591735139159898, 2.34983942529952), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0552268786725883), PC.aa.C38.5 = list(
#  .         metabolite.id = "PC.aa.C38.5", metabolite.full.name = "PC aa C38:5",
#  .         boxplot.stats = structure(c(-2.56154554356102, -0.716813897244536,
#  .         0.0838716445226216, 0.657440130342477, 2.66269497558342,
#  .         -2.4440342900681, -0.665994890424988, -0.0291896956318018,
#  .         0.528532891724765, 2.26823805139016), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.289133254082972), PC.aa.C38.6 = list(
#  .         metabolite.id = "PC.aa.C38.6", metabolite.full.name = "PC aa C38:6",
#  .         boxplot.stats = structure(c(-2.53955273078612, -0.622091414879368,
#  .         0.062729612648906, 0.791447854511603, 2.568272474915,
#  .         -2.78027663782333, -0.77653806592536, -0.0725216357148234,
#  .         0.619560130499505, 2.44052126110884), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0436627656362585), PC.aa.C40.2 = list(
#  .         metabolite.id = "PC.aa.C40.2", metabolite.full.name = "PC aa C40:2",
#  .         boxplot.stats = structure(c(-2.28923628052369, -0.670054765448539,
#  .         -0.036130211425387, 0.645481821774995, 2.45161434063095,
#  .         -2.60423782468267, -0.699814728327317, 0.011555267788556,
#  .         0.601012361203274, 2.53484056439415), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.804847716259262), PC.aa.C40.3 = list(
#  .         metabolite.id = "PC.aa.C40.3", metabolite.full.name = "PC aa C40:3",
#  .         boxplot.stats = structure(c(-2.70589640293757, -0.679194784702563,
#  .         -0.0532929531487153, 0.730110730741196, 2.64870000852909,
#  .         -2.53872670692125, -0.747644229585477, -0.0644138306960343,
#  .         0.597881026662207, 2.53477623851558), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.434922983178379), PC.aa.C40.4 = list(
#  .         metabolite.id = "PC.aa.C40.4", metabolite.full.name = "PC aa C40:4",
#  .         boxplot.stats = structure(c(-2.62654761936802, -0.683729251341582,
#  .         0.0524907861666366, 0.749314589091126, 2.58450085277397,
#  .         -2.39560180140181, -0.684152925074635, -0.00971626063395897,
#  .         0.555317061263067, 2.30445205463273), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.319257361665206), PC.aa.C40.5 = list(
#  .         metabolite.id = "PC.aa.C40.5", metabolite.full.name = "PC aa C40:5",
#  .         boxplot.stats = structure(c(-2.59004238674091, -0.711853713820931,
#  .         0.0764793748187754, 0.718953723268031, 2.75084918472313,
#  .         -2.26288473574244, -0.656784978600234, -0.0377151531421148,
#  .         0.620682995555851, 2.35189277024638), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.511540549285441), PC.aa.C40.6 = list(
#  .         metabolite.id = "PC.aa.C40.6", metabolite.full.name = "PC aa C40:6",
#  .         boxplot.stats = structure(c(-2.63696699284353, -0.635782092777758,
#  .         0.0263666237571751, 0.759351351421988, 2.50131462741494,
#  .         -2.59780444040818, -0.703398008589959, -0.0252452778725188,
#  .         0.610287840986251, 2.47798281970755), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0726722953534283), PC.aa.C42.0 = list(
#  .         metabolite.id = "PC.aa.C42.0", metabolite.full.name = "PC aa C42:0",
#  .         boxplot.stats = structure(c(-2.76864144543734, -0.70663801907861,
#  .         -0.0808880656210482, 0.694420030135458, 2.49010436148747,
#  .         -2.26465445996798, -0.655416531232661, 0.0832569263384323,
#  .         0.700085262408163, 2.59705201597746), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0833301945586671), PC.aa.C42.1 = list(
#  .         metabolite.id = "PC.aa.C42.1", metabolite.full.name = "PC aa C42:1",
#  .         boxplot.stats = structure(c(-2.77635706840528, -0.702611326274847,
#  .         -0.0543633936087456, 0.703482288891799, 2.35412207504209,
#  .         -2.29483333611028, -0.686140074329585, 0.0791025717811743,
#  .         0.732721513739399, 2.57854529856587), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.250214042968642), PC.aa.C42.2 = list(
#  .         metabolite.id = "PC.aa.C42.2", metabolite.full.name = "PC aa C42:2",
#  .         boxplot.stats = structure(c(-2.24393473023272, -0.660904247688165,
#  .         -0.080729878308584, 0.667500348704355, 2.23860271168471,
#  .         -2.28636440099104, -0.677038943390612, -0.131329530217902,
#  .         0.575017261219698, 2.28803708691788), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.332061444569801), PC.aa.C42.4 = list(
#  .         metabolite.id = "PC.aa.C42.4", metabolite.full.name = "PC aa C42:4",
#  .         boxplot.stats = structure(c(-2.5383556089651, -0.683609901586654,
#  .         0.0403468962520358, 0.683696607131742, 2.66600694518438,
#  .         -2.59984897020934, -0.628952213198539, -0.051685716623759,
#  .         0.688393642726288, 2.59478319736082), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.75660347940524), PC.aa.C42.5 = list(
#  .         metabolite.id = "PC.aa.C42.5", metabolite.full.name = "PC aa C42:5",
#  .         boxplot.stats = structure(c(-2.33908813972, -0.638332996751259,
#  .         -0.0324377249446547, 0.673137438053116, 2.63330973421418,
#  .         -2.48865694536059, -0.706452229371715, -0.0245480740572314,
#  .         0.515080650265549, 2.32275787962481), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.320515402726393), PC.aa.C42.6 = list(
#  .         metabolite.id = "PC.aa.C42.6", metabolite.full.name = "PC aa C42:6",
#  .         boxplot.stats = structure(c(-2.01180602963899, -0.610767096013246,
#  .         0.00196336648698647, 0.634134874088357, 2.32471184775107,
#  .         -2.47659849347873, -0.753744028601193, -0.0491635955826763,
#  .         0.584267021786726, 2.52413397638985), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.173278722330698), PC.ae.C30.0 = list(
#  .         metabolite.id = "PC.ae.C30.0", metabolite.full.name = "PC ae C30:0",
#  .         boxplot.stats = structure(c(-2.64125203915467, -0.642777925139363,
#  .         -0.04965496794957, 0.700665272564789, 2.52419415866875,
#  .         -2.21702151673012, -0.669290133931607, 0.0266784388710801,
#  .         0.636663612841983, 2.59249772961587), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.441818913651489), PC.ae.C30.2 = list(
#  .         metabolite.id = "PC.ae.C30.2", metabolite.full.name = "PC ae C30:2",
#  .         boxplot.stats = structure(c(-2.60563403203876, -0.677607435379461,
#  .         -0.00820698798729719, 0.738116560532053, 2.78173748935551,
#  .         -2.59062558524748, -0.763739389749506, -0.0229439408461029,
#  .         0.636120125031702, 2.49647165691523), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.42179164332705), PC.ae.C32.1 = list(
#  .         metabolite.id = "PC.ae.C32.1", metabolite.full.name = "PC ae C32:1",
#  .         boxplot.stats = structure(c(-2.56448310279803, -0.688593537434959,
#  .         -0.00254722869522081, 0.579052247563785, 2.44383248718425,
#  .         -2.24957775266382, -0.574845754574347, 0.0280019110458005,
#  .         0.548404668595746, 2.18111557834139), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.827556631418004), PC.ae.C32.2 = list(
#  .         metabolite.id = "PC.ae.C32.2", metabolite.full.name = "PC ae C32:2",
#  .         boxplot.stats = structure(c(-2.58757874226869, -0.712141444901441,
#  .         -0.0255824336106794, 0.703882541781327, 2.53916644901274,
#  .         -2.40496272616066, -0.634289753641399, -0.053331095915506,
#  .         0.58189014988694, 2.4061155542219), .Dim = c(5L, 2L)),
#  .         n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.66973437377106), PC.ae.C34.0 = list(
#  .         metabolite.id = "PC.ae.C34.0", metabolite.full.name = "PC ae C34:0",
#  .         boxplot.stats = structure(c(-2.49902611861708, -0.635591019765189,
#  .         -0.0114057721229049, 0.677809809483959, 2.64096008513663,
#  .         -2.52011313569507, -0.619663590534446, 0.000773215015816579,
#  .         0.709148857759062, 2.54943741238849), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.980939334328468), PC.ae.C34.1 = list(
#  .         metabolite.id = "PC.ae.C34.1", metabolite.full.name = "PC ae C34:1",
#  .         boxplot.stats = structure(c(-2.4088114206297, -0.678656284731545,
#  .         -0.010691757657179, 0.655902861921745, 2.64207112873215,
#  .         -2.52602139528851, -0.705677741608538, 0.0432474950653237,
#  .         0.643133385089663, 2.27821617000215), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.880734435062316), PC.ae.C34.2 = list(
#  .         metabolite.id = "PC.ae.C34.2", metabolite.full.name = "PC ae C34:2",
#  .         boxplot.stats = structure(c(-2.54205629343975, -0.652511946558351,
#  .         0.0522629052477136, 0.651696995253574, 2.52675251779118,
#  .         -2.46017051487165, -0.695824568405485, -0.0889592489756287,
#  .         0.685312286351096, 2.75350688302613), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.714170350358456), PC.ae.C34.3 = list(
#  .         metabolite.id = "PC.ae.C34.3", metabolite.full.name = "PC ae C34:3",
#  .         boxplot.stats = structure(c(-2.69618362077469, -0.669522883835936,
#  .         -0.00233714242383876, 0.70538562716211, 2.70777136421687,
#  .         -2.24484884647604, -0.719284073108796, -0.0574703195549672,
#  .         0.600321809229099, 2.49906425725861), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.240544153252442), PC.ae.C36.0 = list(
#  .         metabolite.id = "PC.ae.C36.0", metabolite.full.name = "PC ae C36:0",
#  .         boxplot.stats = structure(c(-2.05250540842305, -0.670285225582358,
#  .         -0.0749360078020653, 0.671840362349589, 2.62706468455065,
#  .         -2.31319438860732, -0.661653200662454, -0.0373555014624161,
#  .         0.528828500430513, 2.20144183504813), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.437870736434704), PC.ae.C36.1 = list(
#  .         metabolite.id = "PC.ae.C36.1", metabolite.full.name = "PC ae C36:1",
#  .         boxplot.stats = structure(c(-2.69090672133916, -0.688661575450313,
#  .         0.00366248982799188, 0.695731607422156, 2.73031297429534,
#  .         -2.42576968361247, -0.660902677482827, -0.0863736990543923,
#  .         0.693757585749751, 2.46367380572022), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.565862460117259), PC.ae.C36.2 = list(
#  .         metabolite.id = "PC.ae.C36.2", metabolite.full.name = "PC ae C36:2",
#  .         boxplot.stats = structure(c(-2.50437670186945, -0.63884274205085,
#  .         0.0547212829687444, 0.699304627599342, 2.61893763532074,
#  .         -2.50624313087474, -0.695208984352287, -0.049607198131075,
#  .         0.688671874788233, 2.61852407653492), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.671326973794426), PC.ae.C36.3 = list(
#  .         metabolite.id = "PC.ae.C36.3", metabolite.full.name = "PC ae C36:3",
#  .         boxplot.stats = structure(c(-2.55954834850798, -0.666256968663952,
#  .         -0.0320578276313754, 0.618291709054543, 2.24374176147597,
#  .         -2.77159877318041, -0.721237666717875, -0.0310801464094476,
#  .         0.663869070481086, 2.50419936557387), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.702534666982945), PC.ae.C36.4 = list(
#  .         metabolite.id = "PC.ae.C36.4", metabolite.full.name = "PC ae C36:4",
#  .         boxplot.stats = structure(c(-2.80747928431701, -0.666279090282903,
#  .         -0.021045311527237, 0.810313336061741, 2.95738287401986,
#  .         -2.4183583617742, -0.653260557186807, -0.114231130055799,
#  .         0.609836972086108, 2.04075458691275), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.14581678853452), PC.ae.C36.5 = list(
#  .         metabolite.id = "PC.ae.C36.5", metabolite.full.name = "PC ae C36:5",
#  .         boxplot.stats = structure(c(-2.66803498923894, -0.663840441932135,
#  .         0.077162447544229, 0.744673370544635, 2.6040561035982,
#  .         -2.4488206785331, -0.676890757798353, -0.0734923929756829,
#  .         0.522108098771401, 2.05988468992619), .Dim = c(5L, 2L
#  .         )), n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0254621657597177), PC.ae.C38.0 = list(
#  .         metabolite.id = "PC.ae.C38.0", metabolite.full.name = "PC ae C38:0",
#  .         boxplot.stats = structure(c(-2.18289950621641, -0.582524908294652,
#  .         0.0413664854987309, 0.621397351056289, 2.32130291603049,
#  .         -2.56910397762292, -0.717177182404071, -0.054644036603803,
#  .         0.531073527585698, 2.2483664860224), .Dim = c(5L, 2L)),
#  .         n.per.group = c(362, 302), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0831417351064515), PC.ae.C38.3 = list(
#  .         metabolite.id = "PC.ae.C38.3", metabolite.full.name = "PC ae C38:3",
#  .         boxplot.stats = structure(c(-2.53048252490318, -0.644428943315539,
#  .         -0.0382230577985332, 0.64351512756527, 2.49533558616791,
#  .         -2.34778612006376, -0.639208182457353, -0.0205596062354855,
#  .         0.607329625579785, 2.0702765202178), .Dim = c(5L, 2L)),
#  .         n.per.group = c(362, 302), boxplot.group.names = c("CN",
# ...
#  .         boxplot.stats = structure(c(-2.3108123833237, -0.566558116507458,
#  .         0.0614280506575559, 0.726533436553373, 2.38191766524958,
#  .         -2.46091367925678, -0.770413547745163, -0.0604279118220206,
#  .         0.571273853171749, 2.41934629976804), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.189724584526087), DCA = list(
#  .         metabolite.id = "DCA", metabolite.full.name = "Deoxycholate",
#  .         boxplot.stats = structure(c(-2.25193504857869, -0.587970558088905,
#  .         0.038890414110644, 0.579197630124475, 2.02347851093714,
#  .         -2.19233403258991, -0.430676875809951, 0.223918330333911,
#  .         0.768589481489576, 1.96448808877127), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.00531761832063542), GCA = list(
#  .         metabolite.id = "GCA", metabolite.full.name = "Glycocholate",
#  .         boxplot.stats = structure(c(-2.79541870632229, -0.718796321959598,
#  .         -0.191273515233116, 0.678562052598884, 2.67171689295366,
#  .         -2.14676958913731, -0.634897158873945, -0.0717529732167729,
#  .         0.771822420106197, 2.43413033009383), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.281860591894945), GCDCA = list(
#  .         metabolite.id = "GCDCA", metabolite.full.name = "Glycochenodeoxycholate",
#  .         boxplot.stats = structure(c(-2.692982276904, -0.782354154631993,
#  .         -0.105664664642405, 0.695579306775196, 2.66392088433009,
#  .         -2.18679061182182, -0.569942741869531, 0.0859770662439016,
#  .         0.840623491122032, 2.54703082239045), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0381092698355411), GDCA = list(
#  .         metabolite.id = "GDCA", metabolite.full.name = "Glycodeoxycholate",
#  .         boxplot.stats = structure(c(-2.49167204989435, -0.764418097815755,
#  .         -0.117782290906005, 0.525370529344664, 2.38281195252976,
#  .         -2.48361805793849, -0.488237703005146, 0.180155319669028,
#  .         0.871703532402423, 2.90378366585891), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.000188733503366063),
#  .     GLCA = list(metabolite.id = "GLCA", metabolite.full.name = "Glycolithocholate",
#  .         boxplot.stats = structure(c(-1.52864561043324, -1.12818030485173,
#  .         -0.172170059696743, 0.497013111032033, 2.15843355797155,
#  .         -1.52663219170559, -0.537064572666569, 0.346323967634178,
#  .         0.940846064426037, 3.13884543955511), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 2.74528432376784e-06),
#  .     GUDCA = list(metabolite.id = "GUDCA", metabolite.full.name = "Glycoursodeoxycholate",
#  .         boxplot.stats = structure(c(-2.2790080117211, -0.727323768341874,
#  .         -0.10030498437511, 0.602847132644045, 2.55315745823781,
#  .         -2.3236995182944, -0.57676146837995, 0.0150249078829758,
#  .         0.737318048025519, 2.52939934998741), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0638253693387149), TCA = list(
#  .         metabolite.id = "TCA", metabolite.full.name = "Taurocholate",
#  .         boxplot.stats = structure(c(-1.59037324843786, -1.23349443397354,
#  .         0.16394673890155, 0.764825681720067, 2.98824675871419,
#  .         -1.56299429265702, -1.17872719322303, 0.137271506895045,
#  .         0.68586845583663, 2.76441015131799), .Dim = c(5L, 2L)),
#  .         n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.54845925675969), TCDCA = list(
#  .         metabolite.id = "TCDCA", metabolite.full.name = "Taurochenodeoxycholate",
#  .         boxplot.stats = structure(c(-2.37887561657453, -0.694433750673561,
#  .         -0.10591074117776, 0.697028792724217, 2.69192186462754,
#  .         -2.27161009403059, -0.737209009071853, 0.0304311416688703,
#  .         0.758362665892659, 2.76362025918227), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.531334969042625), TDCA = list(
#  .         metabolite.id = "TDCA", metabolite.full.name = "Taurodeoxycholate",
#  .         boxplot.stats = structure(c(-2.5242779108863, -0.694711364001754,
#  .         -0.130149166345282, 0.56629347089644, 2.23027599606925,
#  .         -2.43569281971599, -0.632348589071569, 0.00254619358377898,
#  .         0.799511268338402, 2.66980654947909), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.0146535145760939), TLCA = list(
#  .         metabolite.id = "TLCA", metabolite.full.name = "Taurolithocholate",
#  .         boxplot.stats = structure(c(-1.48999958099278, -1.19796779453766,
#  .         -0.0292064169626293, 0.643753798135743, 2.22065835238148,
#  .         -1.57744867661394, -0.794893816185623, 0.171720540714852,
#  .         0.836301133119349, 3.15495614522624), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.00150766475627015), TMCA.A.B. = list(
#  .         metabolite.id = "TMCA.A.B.", metabolite.full.name = "Tauromurocholate (a + b)",
#  .         boxplot.stats = structure(c(-1.74505247494747, -0.701460510738029,
#  .         -0.0705456922065325, 0.537316333803562, 2.25328534660801,
#  .         -1.85182774783617, -0.554692600224229, 0.049310424165724,
#  .         0.823659414928056, 2.84142808640001), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.132089235855028), TUDCA = list(
#  .         metabolite.id = "TUDCA", metabolite.full.name = "Tauroursodeoxycholate",
#  .         boxplot.stats = structure(c(-2.1845469030237, -0.606972236884841,
#  .         -0.0661884358055862, 0.449747560818652, 2.01800158194126,
#  .         -2.2556905868706, -0.509444806155272, -0.0289137133878272,
#  .         0.682311545902108, 2.41249042463964), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.101650320046398), UDCA = list(
#  .         metabolite.id = "UDCA", metabolite.full.name = "Ursodeoxycholate",
#  .         boxplot.stats = structure(c(-2.05837182887244, -0.604202214115565,
#  .         0.126114103273715, 0.738413038812161, 2.53274585403346,
#  .         -2.02179275695707, -1.17496517787993, -0.0437311790177602,
#  .         0.742971166294375, 2.40564530506118), .Dim = c(5L, 2L
#  .         )), n.per.group = c(365, 303), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.237402471751262), Cholesterol = list(
#  .         metabolite.id = "Cholesterol", metabolite.full.name = "Cholesterol (total)",
#  .         boxplot.stats = structure(c(-2.3796419438246, -0.67262659778124,
#  .         -0.0044995185591436, 0.59413668796056, 2.45886202380598,
#  .         -2.66578708137564, -0.606274011641793, 0.0839828374562121,
#  .         0.772205176609824, 2.33662341858802), .Dim = c(5L, 2L
#  .         )), n.per.group = c(402, 304), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.450609169333219), Triglycerides = list(
#  .         metabolite.id = "Triglycerides", metabolite.full.name = "Triglycerides (total)",
#  .         boxplot.stats = structure(c(-2.513407459996, -0.655852624987558,
#  .         -0.106188152578937, 0.609272554508119, 2.26896422292698,
#  .         -2.22769680209785, -0.567613128263519, -0.0728531888890241,
#  .         0.578273378115136, 2.17475902762996), .Dim = c(5L, 2L
#  .         )), n.per.group = c(402, 304), boxplot.group.names = c("CN",
#  .         "AD"), AD.diagnosis.p.value = 0.904043668985855), check.names = TRUE,
#  .     fix.empty.names = TRUE, stringsAsFactors = FALSE)
# 8. as.data.frame(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
# 9. as.data.frame.list(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
# 10. do.call(data.frame, c(x, alis))
# 11. (function (..., row.names = NULL, check.rows = FALSE, check.names = TRUE,
#   .     fix.empty.names = TRUE, stringsAsFactors = default.stringsAsFactors())
#   . {
#   .     data.row.names <- if (check.rows && is.null(row.names))
#   .         function(current, new, i) {
#   .             if (is.character(current))
#   .                 new <- as.character(new)
#   .             if (is.character(new))
#   .                 current <- as.character(current)
#   .             if (anyDuplicated(new))
#   .                 return(current)
#   .             if (is.null(current))
#   .                 return(new)
#   .             if (all(current == new) || all(current == ""))
#   .                 return(new)
#   .             stop(gettextf("mismatch of row names in arguments of 'data.frame', item %d",
#   .                 i), domain = NA)
#   .         }
#   .     else function(current, new, i) {
#   .         if (is.null(current)) {
#   .             if (anyDuplicated(new)) {
#   .                 warning(gettextf("some row.names duplicated: %s --> row.names NOT used",
#   .                   paste(which(duplicated(new)), collapse = ",")),
#   .                   domain = NA)
#   .                 current
#   .             }
#   .             else new
#   .         }
#   .         else current
#   .     }
#   .     object <- as.list(substitute(list(...)))[-1L]
#   .     mirn <- missing(row.names)
#   .     mrn <- is.null(row.names)
#   .     x <- list(...)
#   .     n <- length(x)
#   .     if (n < 1L) {
#   .         if (!mrn) {
#   .             if (is.object(row.names) || !is.integer(row.names))
#   .                 row.names <- as.character(row.names)
#   .             if (anyNA(row.names))
#   .                 stop("row names contain missing values")
#   .             if (anyDuplicated(row.names))
#   .                 stop(gettextf("duplicate row.names: %s", paste(unique(row.names[duplicated(row.names)]),
#   .                   collapse = ", ")), domain = NA)
#   .         }
#   .         else row.names <- integer()
#   .         return(structure(list(), names = character(), row.names = row.names,
#   .             class = "data.frame"))
#   .     }
#   .     vnames <- names(x)
#   .     if (length(vnames) != n)
#   .         vnames <- character(n)
#   .     no.vn <- !nzchar(vnames)
#   .     vlist <- vnames <- as.list(vnames)
#   .     nrows <- ncols <- integer(n)
#   .     for (i in seq_len(n)) {
#   .         xi <- if (is.character(x[[i]]) || is.list(x[[i]]))
#   .             as.data.frame(x[[i]], optional = TRUE, stringsAsFactors = stringsAsFactors)
#   .         else as.data.frame(x[[i]], optional = TRUE)
#   .         nrows[i] <- .row_names_info(xi)
#   .         ncols[i] <- length(xi)
#   .         namesi <- names(xi)
#   .         if (ncols[i] > 1L) {
#   .             if (length(namesi) == 0L)
#   .                 namesi <- seq_len(ncols[i])
#   .             vnames[[i]] <- if (no.vn[i])
#   .                 namesi
#   .             else paste(vnames[[i]], namesi, sep = ".")
#   .         }
#   .         else if (length(namesi)) {
#   .             vnames[[i]] <- namesi
#   .         }
#   .         else if (fix.empty.names && no.vn[[i]]) {
#   .             tmpname <- deparse(object[[i]], nlines = 1L)[1L]
#   .             if (startsWith(tmpname, "I(") && endsWith(tmpname,
#   .                 ")")) {
#   .                 ntmpn <- nchar(tmpname, "c")
#   .                 tmpname <- substr(tmpname, 3L, ntmpn - 1L)
#   .             }
#   .             vnames[[i]] <- tmpname
#   .         }
#   .         if (mirn && nrows[i] > 0L) {
#   .             rowsi <- attr(xi, "row.names")
#   .             if (any(nzchar(rowsi)))
#   .                 row.names <- data.row.names(row.names, rowsi,
#   .                   i)
#   .         }
#   .         nrows[i] <- abs(nrows[i])
#   .         vlist[[i]] <- xi
#   .     }
#   .     nr <- max(nrows)
#   .     for (i in seq_len(n)[nrows < nr]) {
#   .         xi <- vlist[[i]]
#   .         if (nrows[i] > 0L && (nr%%nrows[i] == 0L)) {
#   .             xi <- unclass(xi)
#   .             fixed <- TRUE
#   .             for (j in seq_along(xi)) {
#   .                 xi1 <- xi[[j]]
#   .                 if (is.vector(xi1) || is.factor(xi1))
#   .                   xi[[j]] <- rep(xi1, length.out = nr)
#   .                 else if (is.character(xi1) && inherits(xi1, "AsIs"))
#   .                   xi[[j]] <- structure(rep(xi1, length.out = nr),
#   .                     class = class(xi1))
#   .                 else if (inherits(xi1, "Date") || inherits(xi1,
#   .                   "POSIXct"))
#   .                   xi[[j]] <- rep(xi1, length.out = nr)
#   .                 else {
#   .                   fixed <- FALSE
#   .                   break
#   .                 }
#   .             }
#   .             if (fixed) {
#   .                 vlist[[i]] <- xi
#   .                 next
#   .             }
#   .         }
#   .         stop(gettextf("arguments imply differing number of rows: %s",
#   .             paste(unique(nrows), collapse = ", ")), domain = NA)
#   .     }
#   .     value <- unlist(vlist, recursive = FALSE, use.names = FALSE)
#   .     vnames <- as.character(unlist(vnames[ncols > 0L]))
#   .     if (fix.empty.names && any(noname <- !nzchar(vnames)))
#   .         vnames[noname] <- paste0("Var.", seq_along(vnames))[noname]
#   .     if (check.names) {
#   .         if (fix.empty.names)
#   .             vnames <- make.names(vnames, unique = TRUE)
#   .         else {
#   .             nz <- nzchar(vnames)
#   .             vnames[nz] <- make.names(vnames[nz], unique = TRUE)
#   .         }
#   .     }
#   .     names(value) <- vnames
#   .     if (!mrn) {
#   .         if (length(row.names) == 1L && nr != 1L) {
#   .             if (is.character(row.names))
#   .                 row.names <- match(row.names, vnames, 0L)
#   .             if (length(row.names) != 1L || row.names < 1L ||
#   .                 row.names > length(vnames))
#   .                 stop("'row.names' should specify one of the variables")
#   .             i <- row.names
#   .             row.names <- value[[i]]
#   .             value <- value[-i]
#   .         }
#   .         else if (!is.null(row.names) && length(row.names) !=
#   .             nr)
#   .             stop("row names supplied are of the wrong length")
#   .     }
#   .     else if (!is.null(row.names) && length(row.names) != nr) {
#   .         warning("row names were found from a short variable and have been discarded")
#   .         row.names <- NULL
#   .     }
#   .     class(value) <- "data.frame"
#   .     if (is.null(row.names))
#   .         attr(value, "row.names") <- .set_row_names(nr)
#   .     else {
#   .         if (is.object(row.names) || !is.integer(row.names))
#   .             row.names <- as.character(row.names)
#   .         if (anyNA(row.names))
#   .             stop("row names contain missing values")
#   .         if (anyDuplicated(row.names))
#   .             stop(gettextf("duplicate row.names: %s", paste(unique(row.names[duplicated(row.names)]),
#   .                 collapse = ", ")), domain = NA)
#   .         row.names(value) <- row.names
#   .     }
#   .     value
#   . })(metabolite.id = "C0", metabolite.full.name = "C0", boxplot.stats = structure(c(-2.24301895074324,
#   . -0.563261791496518, 0.0360000053536109, 0.697211583786713, 2.31925770410694,
#   . -2.3261094167728, -0.616879031427269, -0.0350410744613008, 0.624392218512684,
#   . 2.35297397043231), .Dim = c(5L, 2L)), n.per.group = c(362, 302
#   . ), boxplot.group.names = c("CN", "AD"), AD.diagnosis.p.value = 0.283589608291955,
#   .     check.names = FALSE, fix.empty.names = TRUE, stringsAsFactors = FALSE)
# 12. stop(gettextf("arguments imply differing number of rows: %s",
#   .     paste(unique(nrows), collapse = ", ")), domain = NA)
