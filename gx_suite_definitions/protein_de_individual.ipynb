# %% [markdown]
# # Create Expectation Suite for Protein DE Individual Data

# %% [markdown]
# Due to this dataset's large output file size, the protein_de_individual GX suite definition was generated using AI, rather than using a Jupyter notebook.
#
# For more information, see the information on "Option B" in .cursor/rules/gx-validation-suite-authoring.mdc
